# %%
pip install google-play-scraper
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
from google_play_scraper import Sort, reviews

# App ID e-wallet Indonesia from Play Store
apps = {
    'GoPay': 'com.gojek.app',
    'OVO': 'ovo.id',
    'DANA': 'id.dana'
}

all_reviews = []

# %%
# Extract user reviews for each application
for app_name, app_id in apps.items():
    print(f"Scraping review data for: {app_name}...")

    # Retrieve the 5000 most recent reviews per application
    result, _ = reviews(
        app_id,
        lang='id',
        country='id',
        sort=Sort.NEWEST,
        count=5000
    )

    # Append the application identifier to each review entry
    for item in result:
        item['app_name'] = app_name
        all_reviews.append(item)
# Out:
# Scraping review data for: GoPay...
# Scraping review data for: OVO...
# Scraping review data for: DANA...

# %%
# Convert the extracted raw data into a Pandas DataFrame
df = pd.DataFrame(all_reviews)

# %%
df
# Out:
#                                    reviewId                      userName  \
# 0      55ac731e-d9a9-4a74-bdb8-035d0887b267               Pengguna Google
# 1      ffb3d935-ef19-46c4-b396-526854cf094c               Pengguna Google
# 2      1895f40b-9c34-408d-aaca-92ef44ed4124               Pengguna Google
# 3      4e30e588-ad4e-4832-83c5-7a4b45970f05               Pengguna Google
# 4      b18e9644-15d5-4d08-ade0-8a66dc84a954               Pengguna Google
# ...                                     ...                           ...
# 14995  ca7ec2ee-c592-42ea-80bf-6fdad8d9550c                  Dani Prayoga
# 14996  42a692d0-aa1d-485e-a4b1-0a44a92d083c  Aidilbahsyarbbasir2008 Aidil
# 14997  fdbcb8a0-6668-42a3-98b0-3b1ecbcc0d49        arkanzapermana permana
# 14998  6e12da8d-b292-4834-9bb4-067b8cb75b99                         alvin
# 14999  58ecf4e0-7e94-4c08-a697-368fc934f8e3                     Iyas Spdn
#
#                                                userImage  \
# ...

# %%
# Filter and retain only the relevant attributes
cols_to_keep = ['app_name', 'userName', 'score', 'at', 'content', 'appVersion']
df_clean = df[cols_to_keep]

# Display data summary and preview
print("\nExtraction completed successfully! Preview of the dataset:")
display(df_clean.head())
print(f"\nTotal collected reviews: {len(df_clean)} rows")
# Out:
# Extraction completed successfully! Preview of the dataset:
#   app_name         userName  score                  at  \
# 0    GoPay  Pengguna Google      5 2026-08-30 09:17:40
# 1    GoPay  Pengguna Google      5 2026-08-30 09:12:32
# 2    GoPay  Pengguna Google      3 2026-08-30 08:40:16
# 3    GoPay  Pengguna Google      1 2026-08-30 08:34:03
# 4    GoPay  Pengguna Google      5 2026-08-30 08:21:26
#
#                                              content appVersion
# 0  Mau cepat atau paket hemat selalu tersedia arm...     5.74.1
# 1  Tolong.. potongan untuk driver nya, jangan bes...     5.73.2
# 2                                      gofood lamaaa     5.74.1
# 3  kalo gada driver yg mau ngambil tu coba gausah...       None
# 4                                     so comfortable     5.74.1
# Total collected reviews: 15000 rows

# %%
# Export & Download CSV
df_clean.to_csv('ewallet_reviews.csv', index=False)

from google.colab import files
files.download('ewallet_reviews.csv')
